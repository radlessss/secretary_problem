# %% [markdown]
# <a href="https://colab.research.google.com/github/radlessss/secretary_problem/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/radlessss/secretary_problem.git
# Out:
# fatal: destination path 'secretary_problem' already exists and is not an empty directory.

# %%
# %cd secretary_problem/
# !git pull
#!pip install --force-reinstall -e .
# !{sys.executable} -m pip install --force-reinstall -e .
# %cd ..
# Out:
# /content/secretary_problem/secretary_problem
# remote: Enumerating objects: 9, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (1/1), done.
# remote: Total 5 (delta 3), reused 5 (delta 3), pack-reused 0 (from 0)
# Unpacking objects: 100% (5/5), 420 bytes | 210.00 KiB/s, done.
# From https://github.com/radlessss/secretary_problem
#    f726f19..8ad7572  main       -> origin/main
# Updating f726f19..8ad7572
# Fast-forward
#  src/secretary_package/__init__.py | 6 +++---
#  1 file changed, 3 insertions(+), 3 deletions(-)
# Obtaining file:///content/secretary_problem/secretary_problem
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#   Building editable for secretary_package (pyproject.toml) ... done
# ...

# %%
import pkg_resources
installed_packages = [d.project_name for d in pkg_resources.working_set]
print(installed_packages)
# Out:
# ['Bottleneck', 'Cython', 'Farama-Notifications', 'GDAL', 'PyDrive2', 'PyJWT', 'PySocks', 'Send2Trash', 'absl-py', 'accelerate', 'access', 'affine', 'aiofiles', 'aiohappyeyeballs', 'aiohttp', 'aiosignal', 'aiosqlite', 'alabaster', 'albucore', 'albumentations', 'ale-py', 'alembic', 'altair', 'annotated-doc', 'annotated-types', 'antlr4-python3-runtime', 'anyio', 'anywidget', 'argon2-cffi', 'argon2-cffi-bindings', 'array-record', 'arrow', 'arviz', 'astropy', 'astropy-iers-data', 'astunparse', 'atpublic', 'attrs', 'audioread', 'authlib', 'autograd', 'babel', 'backcall', 'beartype', 'beautifulsoup4', 'betterproto', 'bigframes', 'bigquery-magics', 'bleach', 'blinker', 'blis', 'blobfile', 'blosc2', 'bokeh', 'bqplot', 'branca', 'brotli', 'cachecontrol', 'cachetools', 'catalogue', 'certifi', 'cffi', 'chardet', 'charset-normalizer', 'chex', 'clarabel', 'click', 'click-plugins', 'cligj', 'cloudpathlib', 'cloudpickle', 'cmake', 'cmdstanpy', 'colorcet', 'colorlover', 'colour', 'community', 'confec
# ...

# %%
import traceback
try:
    import secretary-package
except Exception as e:
    traceback.print_exc()
# Out:
# Traceback (most recent call last):
#   File "/tmp/ipython-input-2383080781.py", line 3, in <cell line: 0>
#     import secretary_package
# ModuleNotFoundError: No module named 'secretary_package'
