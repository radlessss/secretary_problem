# %% [markdown]
# <a href="https://colab.research.google.com/github/radlessss/secretary_problem/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/radlessss/secretary_problem.git
# Out:
# Cloning into 'secretary_problem'...
# remote: Enumerating objects: 34, done.
# remote: Counting objects: 100% (34/34), done.
# remote: Compressing objects: 100% (28/28), done.
# remote: Total 34 (delta 6), reused 22 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (34/34), 45.12 KiB | 3.47 MiB/s, done.
# Resolving deltas: 100% (6/6), done.

# %%
# %cd secretary_problem/
# !git pull
# !pip install -e .
# %cd ..
# Out:
# [Errno 2] No such file or directory: 'secretary_problem/'
# /content/secretary_problem/secretary_problem
# Already up to date.
# Obtaining file:///content/secretary_problem/secretary_problem
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Building wheels for collected packages: my-package
#   Building editable for my-package (pyproject.toml) ... done
#   Created wheel for my-package: filename=my_package-0.1.0-0.editable-py3-none-any.whl size=1298 sha256=a989a852ebc0379ba10063f511a2a7614218d757d3fd419c806d84a74532ddbf
#   Stored in directory: /tmp/pip-ephem-wheel-cache-mu9fsio2/wheels/f1/8e/aa/fc092b504ba338090246a6db54e5fe39339abdf4ff2732395e
# Successfully built my-package
# Installing collected packages: my-package
#   Attempting uninstall: my-package
#     Found existing installation: my-package 0.1.0
#     Uninstalling my-package-0.1.0:
#       Successfully uninstalled my-package-0.1.0
# Successfully installed my-package-0.1.0

# %%
from secretary_package.agent import agent_learner  # Ваш оновлений клас CooperativeAgentLearner
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-3135593540.py in <cell line: 0>()
# ----> 1 from secretary_package.agent import agent_learner  # Ваш оновлений клас CooperativeAgentLearner
#
# /content/secretary_problem/secretary_problem/secretary_package/__init__.py in <module>
# ----> 1 from .agent import agent_learner
#       2 from .secretary import CooperativeSecretaryEnv
#       3 from .learn import *
#       4 from .test import *
#       5 from .utilfunctions import scale_state, single_shape_adaptor
#
# /content/secretary_problem/secretary_problem/secretary_package/agent.py in <module>
#       3 from tensorflow import keras
#       4 from tensorflow.keras import layers
# ----> 5 from utilfunctions import scale_state
#       6 import os
#       7
#
# ModuleNotFoundError: No module named 'utilfunctions'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
